# %% [markdown]
# # **Extract, Tranform, dan Load (ETL)**
#
# ETL --> proses untuk memindahkan data dari satu tempat ke tempat lain (dari sumber data ke data warehouse)

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
engine = sqlalchemy.create_engine('postgresql+psycopg2://postgres:postgres@localhost/staging')
conn1 = engine.connect()
# %sql postgresql://postgres:postgres@localhost:5432/staging

# %% [markdown]
# ## Load Data Source

# %%
df_participant = pd.read_csv('https://storage.googleapis.com/dqlab-dataset/dqthon-participants.csv')

# %%
df_participant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   participant_id  5000 non-null   object
#  1   first_name      5000 non-null   object
#  2   last_name       5000 non-null   object
#  3   birth_date      5000 non-null   object
#  4   address         5000 non-null   object
#  5   phone_number    5000 non-null   object
#  6   country         5000 non-null   object
#  7   institute       5000 non-null   object
#  8   occupation      5000 non-null   object
#  9   register_time   5000 non-null   float64
# dtypes: float64(1), object(9)
# memory usage: 390.8+ KB

# %% [markdown]
# **information columns :**
# 1. participant_id : unique value merupakan id participant
# 2. first_name     : nama depan peserta
# 3. last_name      : nama belakang peserta
# 4. birth_date     : informasi tanggal lahir peserta
# 5. phone_number   : informasi nomor telepon peserta
# 6. country        : informasi negara asal peserta
# 7. institute      : informasi institusi peserta
# 8. occupation     : informasi pekerjaan peserta saat ini
# 9. register_time  : informasi waktu peserta mendaftar dalam second

# %% [markdown]
# ## Transform

# %% [markdown]
# ### 1. Transform Kode Pos dari Atribut Alamat

# %% [markdown]
# Atribut Alamat memiliki informasi Nama Jalan, Kabupaten/Kota, Provinsi, dan Kode Pos. Kode Pos merupakan 5 angka yang berada di belakang alamat. Untuk ekstrak kode pos ini akan digunakan fungsi ekstrak dan regex

# %%
df_participant['postal_code'] = df_participant['address'].str.extract(r'(\d+)$')

# %%
df_participant[['address', 'country', 'postal_code']].head(5)
# Out:
#                                              address      country postal_code
# 0           Gg. Monginsidi No. 08\nMedan, Aceh 80734      Georgia       80734
# 1     Gg. Rajawali Timur No. 7\nPrabumulih, MA 09434  Korea Utara       09434
# 2             Jalan Kebonjati No. 0\nAmbon, SS 57739       Komoro       57739
# 3    Jl. Yos Sudarso No. 109\nLubuklinggau, SR 76156      Eritrea       76156
# 4  Jalan Gardujati No. 53\nKediri, Sulawesi Tenga...     Aljazair       70074

# %% [markdown]
# ### 2. Ekstract City Name dari Column Address

# %% [markdown]
# Nama kota dapat kita ekstrak dari kolom adress, kita asumsikan kata nama kota berada setelah '\n' dan sebelum tanda koma. Untuk ekstrak nama kota akan menggunakan regex (?<=\n)(\w.+)(?=,)

# %%
df_participant['city'] = df_participant['address'].str.extract(r'(?<=\n)(\w.+)(?=,)')

# %%
df_participant = df_participant.replace({r'\s+$': '', r'^\s+': ''}, regex=True).replace(r'\n',  ' ', regex=True)

# %%
df_participant[['address', 'country', 'postal_code','city']].head()
# Out:
#                                              address      country postal_code  \
# 0            Gg. Monginsidi No. 08 Medan, Aceh 80734      Georgia       80734
# 1      Gg. Rajawali Timur No. 7 Prabumulih, MA 09434  Korea Utara       09434
# 2              Jalan Kebonjati No. 0 Ambon, SS 57739       Komoro       57739
# 3     Jl. Yos Sudarso No. 109 Lubuklinggau, SR 76156      Eritrea       76156
# 4  Jalan Gardujati No. 53 Kediri, Sulawesi Tengah...     Aljazair       70074
#
#            city
# 0         Medan
# 1    Prabumulih
# 2         Ambon
# 3  Lubuklinggau
# 4        Kediri

# %% [markdown]
# ### 3. Ekstract Link Github From Each Participant

# %% [markdown]
# Kita asumsikan setiap participant memiliki github dengan nama panjangnya

# %%
df_participant['github_profile'] = 'https://github.com/' + df_participant['first_name'].str.lower() + df_participant['last_name'].str.lower()

# %%
df_participant.head()
# Out:
#                          participant_id first_name   last_name   birth_date  \
# 0  bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a      Citra  Nurdiyanti  05 Feb 1991
# 1  7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3       Aris    Setiawan  11 Jan 1993
# 2  19582d7f-b824-4fe5-a517-d5bf573fc768   Cornelia   Handayani  31 Jul 1993
# 3  aeb6d817-25f3-4867-8a74-8d92e0a0f633      Soleh      Rajasa  04 Nov 1991
# 4  1fdabdd9-5444-4c97-87b2-fe8833ad0d27       Vivi      Astuti  22 Jan 2003
#
#                                              address        phone_number  \
# 0            Gg. Monginsidi No. 08 Medan, Aceh 80734     (0151) 081 2706
# 1      Gg. Rajawali Timur No. 7 Prabumulih, MA 09434  +62 (036) 461 7027
# 2              Jalan Kebonjati No. 0 Ambon, SS 57739        089 833 6695
# 3     Jl. Yos Sudarso No. 109 Lubuklinggau, SR 76156  +62 (418) 329-4756
# 4  Jalan Gardujati No. 53 Kediri, Sulawesi Tengah...          0812511835
#
#        country                  institute                      occupation  \
# 0      Georgia       UD Prakasa Mandasari  Business Intelligence Engineer
# 1  Korea Utara     Universitas Diponegoro               Frontend Engineer
# 2       Komoro   UD Hardiansyah Puspasari                Business Analyst
# 3      Eritrea  Perum Tampubolon Yuliarti                 DevOps Engineer
# 4     Aljazair     PT Hardiansyah Rahimah                    Data Analyst
#
#    register_time postal_code          city  \
# 0   1.617634e+09       80734         Medan
# 1   1.617634e+09       09434    Prabumulih
# 2   1.617634e+09       57739         Ambon
# 3   1.617634e+09       76156  Lubuklinggau
# 4   1.617634e+09       70074        Kediri
#
#                          github_profile
# 0    https://github.com/citranurdiyanti
# 1       https://github.com/arissetiawan
# 2  https://github.com/corneliahandayani
# 3        https://github.com/solehrajasa
# 4         https://github.com/viviastuti

# %% [markdown]
# ### 4. Cleansing Column Phone Number

# %% [markdown]
# Melakukan penyeragaman nomor telepon agar memiliki format yang sama.
# 1. Apabila nomor hp berupa angka 62 atau +62 akan diterjemahkan ke 0
# 2. Menghilangkan tanda baca kurung buka, kurung tutup, strip
# 3. Pada phone number seharusnya tidak ada spasi untuk pemisah setiap nomor

# %%
#Masukkan regex anda pada parameter pertama dari fungsi replace
df_participant['phone_number_new'] = df_participant['phone_number'].str.replace(r'^(\+62|62)', '0')
df_participant['phone_number_new'] = df_participant['phone_number_new'].str.replace(r'[()-]', '')
df_participant['phone_number_new'] = df_participant['phone_number_new'].str.replace(r'\s+', '')
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_143712/1634017234.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_participant['phone_number_new'] = df_participant['phone_number'].str.replace(r'^(\+62|62)', '0')
# C:\Users\USER\AppData\Local\Temp/ipykernel_143712/1634017234.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_participant['phone_number_new'] = df_participant['phone_number_new'].str.replace(r'[()-]', '')
# C:\Users\USER\AppData\Local\Temp/ipykernel_143712/1634017234.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_participant['phone_number_new'] = df_participant['phone_number_new'].str.replace(r'\s+', '')

# %%
df_participant.head()
# Out:
#                          participant_id first_name   last_name   birth_date  \
# 0  bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a      Citra  Nurdiyanti  05 Feb 1991
# 1  7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3       Aris    Setiawan  11 Jan 1993
# 2  19582d7f-b824-4fe5-a517-d5bf573fc768   Cornelia   Handayani  31 Jul 1993
# 3  aeb6d817-25f3-4867-8a74-8d92e0a0f633      Soleh      Rajasa  04 Nov 1991
# 4  1fdabdd9-5444-4c97-87b2-fe8833ad0d27       Vivi      Astuti  22 Jan 2003
#
#                                              address        phone_number  \
# 0            Gg. Monginsidi No. 08 Medan, Aceh 80734     (0151) 081 2706
# 1      Gg. Rajawali Timur No. 7 Prabumulih, MA 09434  +62 (036) 461 7027
# 2              Jalan Kebonjati No. 0 Ambon, SS 57739        089 833 6695
# 3     Jl. Yos Sudarso No. 109 Lubuklinggau, SR 76156  +62 (418) 329-4756
# 4  Jalan Gardujati No. 53 Kediri, Sulawesi Tengah...          0812511835
#
#        country                  institute                      occupation  \
# 0      Georgia       UD Prakasa Mandasari  Business Intelligence Engineer
# 1  Korea Utara     Universitas Diponegoro               Frontend Engineer
# 2       Komoro   UD Hardiansyah Puspasari                Business Analyst
# 3      Eritrea  Perum Tampubolon Yuliarti                 DevOps Engineer
# 4     Aljazair     PT Hardiansyah Rahimah                    Data Analyst
#
#    register_time postal_code          city  \
# 0   1.617634e+09       80734         Medan
# 1   1.617634e+09       09434    Prabumulih
# 2   1.617634e+09       57739         Ambon
# 3   1.617634e+09       76156  Lubuklinggau
# 4   1.617634e+09       70074        Kediri
#
#                          github_profile phone_number_new
# 0    https://github.com/citranurdiyanti      01510812706
# 1       https://github.com/arissetiawan      00364617027
# 2  https://github.com/corneliahandayani       0898336695
# 3        https://github.com/solehrajasa      04183294756
# 4         https://github.com/viviastuti       0812511835

# %% [markdown]
# ### 4. Define Team Name

# %% [markdown]
# Mendefinisikan nama tim dari masing-masing peserta
# first_name, last_name, country, dan institute.

# %%
def team_name(col):
    abbrev_name = "%s%s"%(col['first_name'][0],col['last_name'][0]) #Singkatan dari Nama Depan dan Nama Belakang dengan mengambil huruf pertama
    country = col['country']
    abbrev_institute = '%s'%(''.join(list(map(lambda word: word[0], col['institute'].split())))) #Singkatan dari value di kolom institute
    return "%s-%s-%s"%(abbrev_name,country,abbrev_institute)

df_participant['team_name'] = df_participant.apply(team_name, axis=1)

# %%
df_participant.head()
# Out:
#                          participant_id first_name   last_name   birth_date  \
# 0  bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a      Citra  Nurdiyanti  05 Feb 1991
# 1  7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3       Aris    Setiawan  11 Jan 1993
# 2  19582d7f-b824-4fe5-a517-d5bf573fc768   Cornelia   Handayani  31 Jul 1993
# 3  aeb6d817-25f3-4867-8a74-8d92e0a0f633      Soleh      Rajasa  04 Nov 1991
# 4  1fdabdd9-5444-4c97-87b2-fe8833ad0d27       Vivi      Astuti  22 Jan 2003
#
#                                              address        phone_number  \
# 0            Gg. Monginsidi No. 08 Medan, Aceh 80734     (0151) 081 2706
# 1      Gg. Rajawali Timur No. 7 Prabumulih, MA 09434  +62 (036) 461 7027
# 2              Jalan Kebonjati No. 0 Ambon, SS 57739        089 833 6695
# 3     Jl. Yos Sudarso No. 109 Lubuklinggau, SR 76156  +62 (418) 329-4756
# 4  Jalan Gardujati No. 53 Kediri, Sulawesi Tengah...          0812511835
#
#        country                  institute                      occupation  \
# 0      Georgia       UD Prakasa Mandasari  Business Intelligence Engineer
# 1  Korea Utara     Universitas Diponegoro               Frontend Engineer
# 2       Komoro   UD Hardiansyah Puspasari                Business Analyst
# 3      Eritrea  Perum Tampubolon Yuliarti                 DevOps Engineer
# 4     Aljazair     PT Hardiansyah Rahimah                    Data Analyst
#
#    register_time postal_code          city  \
# 0   1.617634e+09       80734         Medan
# 1   1.617634e+09       09434    Prabumulih
# 2   1.617634e+09       57739         Ambon
# 3   1.617634e+09       76156  Lubuklinggau
# 4   1.617634e+09       70074        Kediri
#
#                          github_profile phone_number_new          team_name
# 0    https://github.com/citranurdiyanti      01510812706     CN-Georgia-UPM
# 1       https://github.com/arissetiawan      00364617027  AS-Korea Utara-UD
# 2  https://github.com/corneliahandayani       0898336695      CH-Komoro-UHP
# 3        https://github.com/solehrajasa      04183294756     SR-Eritrea-PTY
# 4         https://github.com/viviastuti       0812511835    VA-Aljazair-PHR

# %% [markdown]
# ### 5. Transform Email

# %% [markdown]
# Dibutuhkan informasi berupa email, namun informasi tersebut belum tersedia sehingga email akan didefinisikan sebagai berikut:
#     - format email:
#         xxyy@aa.bb.[ac/com].[cc]
#         dengan:
#         ` xx --> first_name (lowercase) ` ,
#         ` yy --> last_name (lowercase) ` ,
#         ` aa --> institusi `,
#         ` cc --> negara asal peserta `.
#         ` ac/com --> apabila universitas (ac), apabila institusi (com)`
#
#     - nilai bb dan cc mengikuti nilai dari aa. aturannya:
#       - Jika institusi merupakan Universitas, maka
#         bb --> gabungan dari huruf pertama pada setiap kata dari nama Universitas dalam lowercase.

# %%
def func(col):
    first_name_lower = col['first_name'].lower()
    last_name_lower = col['last_name'].lower()
    institute = ''.join(list(map(lambda word: word[0], col['institute'].lower().split()))) #Singkatan dari nama perusahaan dalam lowercase

    if 'Universitas' in col['institute']:
        if len(col['country'].split()) > 1: #Kondisi untuk mengecek apakah jumlah kata dari country lebih dari 1
            country = ''.join(list(map(lambda word: word[0], col['country'].lower().split())))
        else:
            country = col['country'][:3].lower()
        return "%s%s@%s.ac.%s"%(first_name_lower,last_name_lower,institute,country)

    return "%s%s@%s.com"%(first_name_lower,last_name_lower,institute)

df_participant['email'] = df_participant.apply(func, axis=1)

# %%
df_participant.head()
# Out:
#                          participant_id first_name   last_name   birth_date  \
# 0  bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a      Citra  Nurdiyanti  05 Feb 1991
# 1  7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3       Aris    Setiawan  11 Jan 1993
# 2  19582d7f-b824-4fe5-a517-d5bf573fc768   Cornelia   Handayani  31 Jul 1993
# 3  aeb6d817-25f3-4867-8a74-8d92e0a0f633      Soleh      Rajasa  04 Nov 1991
# 4  1fdabdd9-5444-4c97-87b2-fe8833ad0d27       Vivi      Astuti  22 Jan 2003
#
#                                              address        phone_number  \
# 0            Gg. Monginsidi No. 08 Medan, Aceh 80734     (0151) 081 2706
# 1      Gg. Rajawali Timur No. 7 Prabumulih, MA 09434  +62 (036) 461 7027
# 2              Jalan Kebonjati No. 0 Ambon, SS 57739        089 833 6695
# 3     Jl. Yos Sudarso No. 109 Lubuklinggau, SR 76156  +62 (418) 329-4756
# 4  Jalan Gardujati No. 53 Kediri, Sulawesi Tengah...          0812511835
#
#        country                  institute                      occupation  \
# 0      Georgia       UD Prakasa Mandasari  Business Intelligence Engineer
# 1  Korea Utara     Universitas Diponegoro               Frontend Engineer
# 2       Komoro   UD Hardiansyah Puspasari                Business Analyst
# 3      Eritrea  Perum Tampubolon Yuliarti                 DevOps Engineer
# 4     Aljazair     PT Hardiansyah Rahimah                    Data Analyst
#
#    register_time postal_code          city  \
# 0   1.617634e+09       80734         Medan
# 1   1.617634e+09       09434    Prabumulih
# 2   1.617634e+09       57739         Ambon
# 3   1.617634e+09       76156  Lubuklinggau
# 4   1.617634e+09       70074        Kediri
#
#                          github_profile phone_number_new          team_name  \
# 0    https://github.com/citranurdiyanti      01510812706     CN-Georgia-UPM
# 1       https://github.com/arissetiawan      00364617027  AS-Korea Utara-UD
# 2  https://github.com/corneliahandayani       0898336695      CH-Komoro-UHP
# 3        https://github.com/solehrajasa      04183294756     SR-Eritrea-PTY
# 4         https://github.com/viviastuti       0812511835    VA-Aljazair-PHR
#
#                        email
# 0    citranurdiyanti@upm.com
# 1      arissetiawan@ud.ac.ku
# 2  corneliahandayani@uhp.com
# 3        solehrajasa@pty.com
# 4         viviastuti@phr.com

# %% [markdown]
# ### 6. Transform Birth Date menjadi format yang sama

# %%
df_participant['birth_date'] = pd.to_datetime(df_participant['birth_date'], format='%d %b %Y')

# %%
df_participant.head()
# Out:
#                          participant_id first_name   last_name birth_date  \
# 0  bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a      Citra  Nurdiyanti 1991-02-05
# 1  7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3       Aris    Setiawan 1993-01-11
# 2  19582d7f-b824-4fe5-a517-d5bf573fc768   Cornelia   Handayani 1993-07-31
# 3  aeb6d817-25f3-4867-8a74-8d92e0a0f633      Soleh      Rajasa 1991-11-04
# 4  1fdabdd9-5444-4c97-87b2-fe8833ad0d27       Vivi      Astuti 2003-01-22
#
#                                              address        phone_number  \
# 0            Gg. Monginsidi No. 08 Medan, Aceh 80734     (0151) 081 2706
# 1      Gg. Rajawali Timur No. 7 Prabumulih, MA 09434  +62 (036) 461 7027
# 2              Jalan Kebonjati No. 0 Ambon, SS 57739        089 833 6695
# 3     Jl. Yos Sudarso No. 109 Lubuklinggau, SR 76156  +62 (418) 329-4756
# 4  Jalan Gardujati No. 53 Kediri, Sulawesi Tengah...          0812511835
#
#        country                  institute                      occupation  \
# 0      Georgia       UD Prakasa Mandasari  Business Intelligence Engineer
# 1  Korea Utara     Universitas Diponegoro               Frontend Engineer
# 2       Komoro   UD Hardiansyah Puspasari                Business Analyst
# 3      Eritrea  Perum Tampubolon Yuliarti                 DevOps Engineer
# 4     Aljazair     PT Hardiansyah Rahimah                    Data Analyst
#
#    register_time postal_code          city  \
# 0   1.617634e+09       80734         Medan
# 1   1.617634e+09       09434    Prabumulih
# 2   1.617634e+09       57739         Ambon
# 3   1.617634e+09       76156  Lubuklinggau
# 4   1.617634e+09       70074        Kediri
#
#                          github_profile phone_number_new          team_name  \
# 0    https://github.com/citranurdiyanti      01510812706     CN-Georgia-UPM
# 1       https://github.com/arissetiawan      00364617027  AS-Korea Utara-UD
# 2  https://github.com/corneliahandayani       0898336695      CH-Komoro-UHP
# 3        https://github.com/solehrajasa      04183294756     SR-Eritrea-PTY
# 4         https://github.com/viviastuti       0812511835    VA-Aljazair-PHR
#
#                        email
# 0    citranurdiyanti@upm.com
# 1      arissetiawan@ud.ac.ku
# 2  corneliahandayani@uhp.com
# 3        solehrajasa@pty.com
# 4         viviastuti@phr.com

# %% [markdown]
# ### 7. Transform Competition Register Time

# %% [markdown]
# Mengubah tipe column register_time menjadi DATETIME (YYYY-MM-DD HH:mm:ss)
#
#     - YYYY: year
#     - MM  : Month
#     - DD  : Day
#     - hh  : Hour
#     - mm  : Minute
#     - ss  : Second

# %%
df_participant['register_at'] = pd.to_datetime(df_participant['register_time'], unit='s')
df_participant.head()
# Out:
#                          participant_id first_name   last_name birth_date  \
# 0  bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a      Citra  Nurdiyanti 1991-02-05
# 1  7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3       Aris    Setiawan 1993-01-11
# 2  19582d7f-b824-4fe5-a517-d5bf573fc768   Cornelia   Handayani 1993-07-31
# 3  aeb6d817-25f3-4867-8a74-8d92e0a0f633      Soleh      Rajasa 1991-11-04
# 4  1fdabdd9-5444-4c97-87b2-fe8833ad0d27       Vivi      Astuti 2003-01-22
#
#                                              address        phone_number  \
# 0            Gg. Monginsidi No. 08 Medan, Aceh 80734     (0151) 081 2706
# 1      Gg. Rajawali Timur No. 7 Prabumulih, MA 09434  +62 (036) 461 7027
# 2              Jalan Kebonjati No. 0 Ambon, SS 57739        089 833 6695
# 3     Jl. Yos Sudarso No. 109 Lubuklinggau, SR 76156  +62 (418) 329-4756
# 4  Jalan Gardujati No. 53 Kediri, Sulawesi Tengah...          0812511835
#
#        country                  institute                      occupation  \
# 0      Georgia       UD Prakasa Mandasari  Business Intelligence Engineer
# 1  Korea Utara     Universitas Diponegoro               Frontend Engineer
# 2       Komoro   UD Hardiansyah Puspasari                Business Analyst
# 3      Eritrea  Perum Tampubolon Yuliarti                 DevOps Engineer
# 4     Aljazair     PT Hardiansyah Rahimah                    Data Analyst
#
#    register_time postal_code          city  \
# 0   1.617634e+09       80734         Medan
# 1   1.617634e+09       09434    Prabumulih
# 2   1.617634e+09       57739         Ambon
# 3   1.617634e+09       76156  Lubuklinggau
# 4   1.617634e+09       70074        Kediri
#
#                          github_profile phone_number_new          team_name  \
# 0    https://github.com/citranurdiyanti      01510812706     CN-Georgia-UPM
# 1       https://github.com/arissetiawan      00364617027  AS-Korea Utara-UD
# 2  https://github.com/corneliahandayani       0898336695      CH-Komoro-UHP
# 3        https://github.com/solehrajasa      04183294756     SR-Eritrea-PTY
# 4         https://github.com/viviastuti       0812511835    VA-Aljazair-PHR
#
#                        email         register_at
# 0    citranurdiyanti@upm.com 2021-04-05 14:47:26
# 1      arissetiawan@ud.ac.ku 2021-04-05 14:46:58
# 2  corneliahandayani@uhp.com 2021-04-05 14:47:15
# 3        solehrajasa@pty.com 2021-04-05 14:47:14
# 4         viviastuti@phr.com 2021-04-05 14:46:50

# %% [markdown]
# *Tambahan

# %% [markdown]
# ### 8. Extract Latitude, Longitude

# %% [markdown]
# #### 5.1 Extract Latitude, Longitude from address

# %%
# from geopy.geocoders import Nominatim
# geolocator = Nominatim



# lat = []
# long = []
# contoh = df_participant.copy()
# for row in contoh['address']:
#     addr = geolocator.geocode(row, timeout=10)
#     if addr:
#         latitude = addr.latitude
#         longitude = addr.longitude
#     else:
#         latitude = None
#         longitude = None  
    
#     lat.append(latitude)
#     long.append(longitude)

# contoh['latitude'] = lat
# contoh['longitude'] = long
# contoh

# %% [markdown]
# ### 7. Memilih kolom yang diperlukan

# %%
df_participant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   participant_id    5000 non-null   object
#  1   first_name        5000 non-null   object
#  2   last_name         5000 non-null   object
#  3   birth_date        5000 non-null   datetime64[ns]
#  4   address           5000 non-null   object
#  5   phone_number      5000 non-null   object
#  6   country           5000 non-null   object
#  7   institute         5000 non-null   object
#  8   occupation        5000 non-null   object
#  9   register_time     5000 non-null   float64
#  10  postal_code       5000 non-null   object
#  11  city              5000 non-null   object
#  12  github_profile    5000 non-null   object
#  13  phone_number_new  5000 non-null   object
#  14  team_name         5000 non-null   object
#  15  email             5000 non-null   object
#  16  register_at       5000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), object(14)
# memory usage: 664.2+ KB

# %%
df_participant_cop = df_participant[['participant_id','first_name','last_name','birth_date','address','city','postal_code','phone_number_new','country','institute','occupation','email','team_name','register_at']].copy()

# %%
df_participant_cop.head()
# Out:
#                          participant_id first_name   last_name birth_date  \
# 0  bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a      Citra  Nurdiyanti 1991-02-05
# 1  7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3       Aris    Setiawan 1993-01-11
# 2  19582d7f-b824-4fe5-a517-d5bf573fc768   Cornelia   Handayani 1993-07-31
# 3  aeb6d817-25f3-4867-8a74-8d92e0a0f633      Soleh      Rajasa 1991-11-04
# 4  1fdabdd9-5444-4c97-87b2-fe8833ad0d27       Vivi      Astuti 2003-01-22
#
#                                              address          city  \
# 0            Gg. Monginsidi No. 08 Medan, Aceh 80734         Medan
# 1      Gg. Rajawali Timur No. 7 Prabumulih, MA 09434    Prabumulih
# 2              Jalan Kebonjati No. 0 Ambon, SS 57739         Ambon
# 3     Jl. Yos Sudarso No. 109 Lubuklinggau, SR 76156  Lubuklinggau
# 4  Jalan Gardujati No. 53 Kediri, Sulawesi Tengah...        Kediri
#
#   postal_code phone_number_new      country                  institute  \
# 0       80734      01510812706      Georgia       UD Prakasa Mandasari
# 1       09434      00364617027  Korea Utara     Universitas Diponegoro
# 2       57739       0898336695       Komoro   UD Hardiansyah Puspasari
# 3       76156      04183294756      Eritrea  Perum Tampubolon Yuliarti
# 4       70074       0812511835     Aljazair     PT Hardiansyah Rahimah
#
#                        occupation                      email  \
# 0  Business Intelligence Engineer    citranurdiyanti@upm.com
# 1               Frontend Engineer      arissetiawan@ud.ac.ku
# 2                Business Analyst  corneliahandayani@uhp.com
# 3                 DevOps Engineer        solehrajasa@pty.com
# 4                    Data Analyst         viviastuti@phr.com
#
#            team_name         register_at
# 0     CN-Georgia-UPM 2021-04-05 14:47:26
# 1  AS-Korea Utara-UD 2021-04-05 14:46:58
# 2      CH-Komoro-UHP 2021-04-05 14:47:15
# 3     SR-Eritrea-PTY 2021-04-05 14:47:14
# 4    VA-Aljazair-PHR 2021-04-05 14:46:50

# %% [markdown]
# ### Store Data to Database

# %%
# df_participant.to_sql(con=conn1, name='tbl_participant', schema='public', index=True)

# %%
# %%sql
#
# select * from tbl_participant
# limit 5
# Out:
#  * postgresql://postgres:***@localhost:5432/staging
# 5 rows affected.
# [(0, 'bd9b6f88-b84f-4c4d-90f8-b67fe2f1a29a', 'Citra', 'Nurdiyanti', datetime.datetime(1991, 2, 5, 0, 0), 'Gg. Monginsidi No. 08 Medan, Aceh 80734', '(0151) 081 2706', 'Georgia', 'UD Prakasa Mandasari', 'Business Intelligence Engineer', 1617634046.0, '80734', 'Medan', 'https://github.com/citranurdiyanti', '01510812706', 'CN-Georgia-UPM', 'citranurdiyanti@upm.com', datetime.datetime(2021, 4, 5, 14, 47, 26)),
#  (1, '7dfe3391-6f40-47b6-b4db-0c76ebaf5fc3', 'Aris', 'Setiawan', datetime.datetime(1993, 1, 11, 0, 0), 'Gg. Rajawali Timur No. 7 Prabumulih, MA 09434', '+62 (036) 461 7027', 'Korea Utara', 'Universitas Diponegoro', 'Frontend Engineer', 1617634018.0, '09434', 'Prabumulih', 'https://github.com/arissetiawan', '00364617027', 'AS-Korea Utara-UD', 'arissetiawan@ud.ac.ku', datetime.datetime(2021, 4, 5, 14, 46, 58)),
#  (2, '19582d7f-b824-4fe5-a517-d5bf573fc768', 'Cornelia', 'Handayani', datetime.datetime(1993, 7, 31, 0, 0), 'Jalan Kebonjati No. 0 Ambon, SS 57739', '089 833 6695', 'Komoro', 'UD Hardiansyah Puspasari', 'Business Analyst', 1617634035.0, '57739', 'Ambon', 'https://github.com/corneliahandayani', '0898336695', 'CH-Komoro-UHP', 'corneliahandayani@uhp.com', datetime.datetime(2021, 4, 5, 14, 47, 15)),
#  (3, 'aeb6d817-25f3-4867-8a74-8d92e0a0f633', 'Soleh', 'Rajasa', datetime.datetime(1991, 11, 4, 0, 0), 'Jl. Yos Sudarso No. 109 Lubuklinggau, SR 76156', '+62 (418) 329-4756', 'Eritrea', 'Perum Tampubolon Yuliarti', 'DevOps Engineer', 1617634034.0, '76156', 'Lubuklinggau', 'https://github.com/solehrajasa', '04183294756', 'SR-Eritrea-PTY', 'solehrajasa@pty.com', datetime.datetime(2021, 4, 5, 14, 47, 14)),
#  (4, '1fdabdd9-5444-4c97-87b2-fe8833ad0d27', 'Vivi', 'Astuti', datetime.datetime(2003, 1, 22, 0, 0), 'Jalan Gardujati No. 53 Kediri, Sulawesi Tengah 70074', '0812511835', 'Aljazair', 'PT Hardiansyah Rahimah', 'Data Analyst', 1617634010.0, '70074', 'Kediri', 'https://github.com/viviastuti', '0812511835', 'VA-Aljazair-PHR', 'viviastuti@phr.com', datetime.datetime(2021, 4, 5, 14, 46, 50))]
